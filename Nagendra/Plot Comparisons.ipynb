# %% [markdown]
# # Task 6

# %% [markdown]
# ## Plot the following Bar plots:
#     0. train score of all the above models.
#     1. test (not validation!) score of all the above models.
#     2. Attempt to explain the observations from the plots (optional)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Restore Knn scores

# %%
# %store -r knn_test_score
# %store -r knn_train_score

# %%
knn_train_score
# Out:
# 0.09831360350558727

# %%
knn_test_score
# Out:
# -0.1212910601653081

# %% [markdown]
# ### Restore Linear scores

# %%
# %store -r linear_test_score
# %store -r linear_train_score

# %%
linear_train_score
# Out:
# 0.00280083687001087

# %%
linear_test_score
# Out:
# 0.005762881017061461

# %% [markdown]
# ### Restore Decision tree scores

# %%
# %store -r decision_train_score
# %store -r decision_test_score

# %%
decision_train_score
# Out:
# 0.9999984196840445

# %%
decision_test_score
# Out:
# 0.9999964408872123

# %%
# For Comparison of all the model store there train values in y variable

x=["knn_train_score","linear_train_score","decision_train_score"]
y =[0.09831360350558727,0.00280083687001087,0.9999984196840445]

# %%
# For Comparison of all the model store there test values in y_1 variable

x_1 = ["knn_test_score","linear_test_score","decision_test_score"]
y_1 =[-0.1212910601653081, 0.005762881017061461,0.9999964408872123]

# %%
plt.figure(dpi=120)
plt.bar(x,y)
plt.xlabel("All Models")
plt.ylabel("Train Scores")
plt.show()

# %% [markdown]
# ### From this we can clearly conclude that best model is decision tree where test score = 0.9999984196840445

# %%
plt.figure(dpi=120)
plt.bar(x_1,y_1)
plt.xlabel("All Models")
plt.ylabel("Test Scores")
plt.show()

# %% [markdown]
# ### From this we can clearly conclude that best model is decision tree where test score = 0.9999964408872123.
